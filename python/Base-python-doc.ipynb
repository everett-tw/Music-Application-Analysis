# %%
import numpy as np
#from numpy import linalg
#import time
#from collections import deque, Counter
#from itertools import permutations, combinations
import statistics
import pandas as pd
import requests
import json

#import api key
import api_keys
output_data_file = "charts.csv"
# title,rank,date,artist,url,region,chart,trend,streams

# %%
output_data_file = pd.read_csv(r"C:\Users\Beep Boop\Documents\GitHub\Project-3\charts.csv")
output_data_file.head(100)
# Out:
#                                                 title  rank        date  \
# 0                  Despacito (Featuring Daddy Yankee)     1  2017-04-01
# 1                                           El Amante     2  2017-04-01
# 2   SUBEME LA RADIO (feat. Descemer Bueno & Zion &...     3  2017-04-01
# 3                                        Shape of You     4  2017-04-01
# 4                                  La Rompe Corazones     5  2017-04-01
# ..                                                ...   ...         ...
# 95                     Don't Let Me Down (feat. Daya)    96  2017-04-01
# 96                      Symphony (feat. Zara Larsson)    97  2017-04-01
# 97         Swalla (feat. Nicki Minaj & Ty Dolla $ign)    98  2017-04-01
# 98                                     Me Ama Me Odia    99  2017-04-01
# 99                                     Vida Tranquila   100  2017-04-01
#
#                        artist  \
# 0                  Luis Fonsi
# 1                   Nicky Jam
# ...

# %%
# api_url = 'theaudiodb.com/api/v1/json/1/mostloved.php?format=album'
# result = requests.get("http//:theaudiodb.com/api/v1/json/1/mostloved.php?format=album")
# result.status_code
# output_data_file = pd.DataFrame(columns=['title', 'rank', 'date', 'artist', 'regon', 'chart'])
# output_data_file.head(100)

output_data_file.head(2)
# Out:
#                                 title  rank        date      artist  \
# 0  Despacito (Featuring Daddy Yankee)     1  2017-04-01  Luis Fonsi
# 1                           El Amante     2  2017-04-01   Nicky Jam
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/4aWmUDTfIPGksMN...  Argentina  top200
# 1  https://open.spotify.com/track/3umS4y3uQDkqekN...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  306716.0
# 1        MOVE_UP  189310.0
